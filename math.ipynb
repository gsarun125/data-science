# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.array ([0,2,5,0,50])
y=np.array([0,6,5,7,0])
plt.plot(x,y)
plt.show()

# %%
import pandas as pd
data=pd.read_csv("E:\data science\dataset\heart_desease_data.csv")
data.head()
x=data.age[data.target==0]
y=data.chol[data.target==0]
plt.scatter(x,y)
plt.show()

# %%
#plt.hist(data.age,bins=5)
plt.boxplot(data.age)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x27937031490>,
#   <matplotlib.lines.Line2D at 0x27937031730>],
#  'caps': [<matplotlib.lines.Line2D at 0x279370319d0>,
#   <matplotlib.lines.Line2D at 0x27937031c70>],
#  'boxes': [<matplotlib.lines.Line2D at 0x279370311f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x27937031f10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2793703f1f0>],
#  'means': []}

# %%
import seaborn as sns
iris=sns.load_dataset("iris")
iris.head()
sns.scatterplot(x="sepal_length",y="petal_length",data=iris)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>
